# %%
from __future__ import annotations

import pandas as pd


def compute_throughput_performance(csv_file, key: str, data_samples: int):
    # Read the CSV file into a DataFrame
    df = pd.read_csv(csv_file)

    print(df)
    print(csv_file)

    # Parse the finished-parsing tag to extract the number of workflow tasks
    # Note: this is a boolean mask with True for rows containing the tag
    finished_tasks = df["tags"].str.contains(key)

    # Filter rows where the tag contains "finished-parsing" to get the total runtime
    total_runtime = df[finished_tasks]["elapsed_s"].sum()

    # Calculate the total finished tasks
    total_finished_tasks = finished_tasks.sum()

    # Calculate the total data processed (tasks * num examples per task)
    total_data_processed = data_samples * total_finished_tasks

    print(df["end_unix"].max())

    # Calculate the total time of the workflow
    total_time = df["end_unix"].max() - df["start_unix"].min()

    # Compute the throughput performance
    throughput_performance = total_data_processed / total_time

    # Create a dictionary to store the results
    results = {
        "total_runtime": total_runtime,
        "total_finished_tasks": total_finished_tasks,
        "total_data_processed": total_data_processed,
        "throughput_performance": throughput_performance,
    }

    print(results)

    return results

# %%
import matplotlib

matplotlib.use("Agg")
from typing import Any

import matplotlib.pyplot as plt
import numpy as np
from matplotlib import font_manager

for fontpath in font_manager.findSystemFonts(fontpaths=None, fontext="ttf"):
    fontlist = []
    if "avenir" in fontpath.lower():
        print(fontpath)
        font_manager.fontManager.addfont(fontpath)
        # font_manager.fontManager.ttflist.extend(fontpath)
        plt.rcParams["font.family"] = "Avenir"

# Set font sizes globally
plt.rcParams["font.size"] = 24
plt.rcParams["axes.titlesize"] = 24
plt.rcParams["axes.labelsize"] = 18
plt.rcParams["xtick.labelsize"] = 16
plt.rcParams["ytick.labelsize"] = 16
plt.rcParams["legend.fontsize"] = 16


def ideal_scaling(x_values: list[Any], y0: float) -> list[Any]:
    """
    return linear strong scaling curve based on x_values, y_values
    """
    x_values = np.array(x_values)
    return [y0 * (x / x_values[0]) for x in x_values]


def plot_scaling_relations(
    x_values: list[list[Any]],
    y_values: list[list[Any]],
    labels: list[str],
    image_name: str,
    ylabel: str = "Throughput (Samples/sec)",
) -> None:
    """
    plot multiple scaling curves for
        each sublist in x_values and y_values
        add ideal scaling based on x_values[1], y_values[1]
        add legend with labels under plot
        save plot to image_name
    """
    # plt.rcParams["font.family"] = "Avenir Regular"
    plt.rcParams["font.size"] = 14
    markers = ["o", "s", "d", "p", "*", "v", "^", "<"]
    colors = [
        "mediumpurple",
        "cornflowerblue",
        "mediumaquamarine",
        "lightcoral",
    ]
    fig, ax = plt.subplots(figsize=(8, 6))
    for x, y, label, marker, color in zip(x_values, y_values, labels, markers, colors):
        ax.plot(x, y, label=label, marker=marker, color=color)
        ax.plot(x, ideal_scaling(x, y[0]), linestyle="--", color="gray", alpha=0.5)
    # set legend below plot
    ax.legend(
        loc="upper left",
        # bbox_to_anchor=(0.5, -0.1),
        shadow=True,
        ncol=1,
        frameon=False,
    )
    ax.set_ylabel(ylabel)
    ax.set_xlabel("Number of accelerators")
    ax.set_yscale("log")
    # step_size=500
    # max_y = max([max(y) for y in y_values])
    # plt.yticks(np.arange(0, max_y+1, step_size))
    ax.set_xscale("log")
    # ax.set_xticks(x_values[0])
    plt.savefig(image_name, bbox_inches="tight")
    plt.show()
# Out:
# /System/Library/Fonts/Avenir.ttc
# /System/Library/Fonts/Avenir Next.ttc
# /System/Library/Fonts/Avenir Next Condensed.ttc

# %%
polaris_semantic_chunking = [
    "scaling/semantic-chunking-polaris/nougat.sfr-mistral.polaris.nodes2.csv",
    "scaling/semantic-chunking-polaris/nougat.sfr-mistral.polaris.nodes32.csv",
    "scaling/semantic-chunking-polaris/nougat.sfr-mistral.polaris.nodes64.csv",
    "scaling/semantic-chunking-polaris/nougat.sfr-mistral.polaris.nodes128.csv",
    "scaling/semantic-chunking-polaris/nougat.sfr-mistral.polaris.nodes256.csv",
]

sunspot_semantic_chunking = [
    "scaling/semantic-chunking-sunspot/nougat.sfr-mistral.sunspot.nodes1.csv",
    "scaling/semantic-chunking-sunspot/nougat.sfr-mistral.sunspot.nodes4.csv",
    "scaling/semantic-chunking-sunspot/nougat.sfr-mistral.sunspot.nodes16.csv",
    "scaling/semantic-chunking-sunspot/nougat.sfr-mistral.sunspot.nodes32.csv",
    # "scaling/semantic-chunking-sunspot/nougat.sfr-mistral.sunspot.nodes64.csv",
    "scaling/semantic-chunking-sunspot/nougat.sfr-mistral.sunspot.nodes96.csv",
]

polaris_semantic_chunking_throughput = [
    compute_throughput_performance(file, "finished-embedding", 93)[
        "throughput_performance"
    ]
    for file in polaris_semantic_chunking
]

sunspot_semantic_chunking_throughput = [
    compute_throughput_performance(file, "finished-embedding", 93)[
        "throughput_performance"
    ]
    for file in sunspot_semantic_chunking
]

polaris_ngpus = [2 * 4, 32 * 4, 64 * 4, 128 * 4, 256 * 4]
sunspot_ngpus = [1 * 12, 4 * 12, 16 * 12, 32 * 12, 96 * 12]

x_values = [polaris_ngpus, sunspot_ngpus]
y_values = [
    polaris_semantic_chunking_throughput,
    sunspot_semantic_chunking_throughput,
]
labels = ["Polaris Semantic Chunking", "Sunspot Semantic Chunking"]
image_name = "scaling_relations_semantic_chunking.pdf"
plot_scaling_relations(x_values, y_values, labels, image_name)

print(
    "Polaris Semantic Chunking Throughput:",
    polaris_semantic_chunking_throughput,
)
print(
    "Sunspot Semantic Chunking Throughput:",
    sunspot_semantic_chunking_throughput,
)
# Out:
#                                                   tags  elapsed_s  \
# 0    ['loaded-encoder', '/lus/eagle/projects/tpc/br...      16.56
# 1    ['loaded-dataset', '/lus/eagle/projects/tpc/br...       0.17
# 2    ['loaded-encoder', '/lus/eagle/projects/tpc/br...      16.76
# 3    ['loaded-dataset', '/lus/eagle/projects/tpc/br...       0.19
# 4    ['loaded-encoder', '/lus/eagle/projects/tpc/br...      16.75
# ..                                                 ...        ...
# 338  ['computed-embeddings', '/lus/eagle/projects/t...     207.77
# 339  ['computed-embeddings', '/lus/eagle/projects/t...     207.52
# 340  ['computed-embeddings', '/lus/eagle/projects/t...     197.77
# 341  ['computed-embeddings', '/lus/eagle/projects/t...     198.26
# 342  ['computed-embeddings', '/lus/eagle/projects/t...     198.47
#
#        start_unix      end_unix
# 0    1.713085e+09  1.713085e+09
# 1    1.713085e+09  1.713085e+09
# 2    1.713085e+09  1.713085e+09
# 3    1.713085e+09  1.713085e+09
# 4    1.713085e+09  1.713085e+09
# ..            ...           ...
# 338  1.713086e+09  1.713087e+09
# 339  1.713086e+09  1.713087e+09
# 340  1.713086e+09  1.713087e+09
# 341  1.713086e+09  1.713087e+09
# 342  1.713086e+09  1.713087e+09
#
# [343 rows x 4 columns]
# scaling/semantic-chunking-polaris/nougat.sfr-mistral.polaris.nodes2.csv
# 1713086557.05
# {'total_runtime': 13063.17, 'total_finished_tasks': 64, 'total_data_processed': 5952, 'throughput_performance': 3.2093865931453514}
#                                                    tags  elapsed_s  \
# 0     ['loaded-encoder', '/lus/eagle/projects/tpc/br...      15.77
# 1     ['loaded-dataset', '/lus/eagle/projects/tpc/br...       0.19
# 2     ['loaded-encoder', '/lus/eagle/projects/tpc/br...      15.80
# 3     ['loaded-dataset', '/lus/eagle/projects/tpc/br...       0.19
# 4     ['loaded-encoder', '/lus/eagle/projects/tpc/br...      16.03
# ...                                                 ...        ...
# 3507  ['wrote-embeddings', '/lus/eagle/projects/tpc/...       0.10
# 3508  ['finished-embedding', '/lus/eagle/projects/tp...     223.76
# 3509  ['loaded-encoder', '/lus/eagle/projects/tpc/br...       0.00
# 3510  ['loaded-dataset', '/lus/eagle/projects/tpc/br...       0.14
# 3511  ['computed-embeddings', '/lus/eagle/projects/t...     230.32
#
#         start_unix      end_unix
# 0     1.713087e+09  1.713087e+09
# 1     1.713087e+09  1.713087e+09
# 2     1.713087e+09  1.713087e+09
# 3     1.713087e+09  1.713087e+09
# 4     1.713087e+09  1.713087e+09
# ...            ...           ...
# 3507  1.713088e+09  1.713088e+09
# 3508  1.713088e+09  1.713088e+09
# 3509  1.713088e+09  1.713088e+09
# 3510  1.713088e+09  1.713088e+09
# 3511  1.713088e+09  1.713088e+09
#
# [3512 rows x 4 columns]
# scaling/semantic-chunking-polaris/nougat.sfr-mistral.polaris.nodes32.csv
# 1713088462.82
# {'total_runtime': 143996.97, 'total_finished_tasks': 651, 'total_data_processed': 60543, 'throughput_performance': 45.565247494383144}
#                                                     tags  elapsed_s  \
# 0      ['loaded-encoder', '/lus/eagle/projects/tpc/br...      85.75
# 1      ['loaded-dataset', '/lus/eagle/projects/tpc/br...       0.19
# 2      ['loaded-encoder', '/lus/eagle/projects/tpc/br...      85.75
# 3      ['loaded-dataset', '/lus/eagle/projects/tpc/br...       0.19
# 4      ['loaded-encoder', '/lus/eagle/projects/tpc/br...      85.75
# ...                                                  ...        ...
# 65777  ['computed-embeddings', '/lus/eagle/projects/t...     199.41
# 65778  ['wrote-embeddings', '/lus/eagle/projects/tpc/...       0.14
# 65779  ['finished-embedding', '/lus/eagle/projects/tp...     200.01
# 65780  ['loaded-encoder', '/lus/eagle/projects/tpc/br...       0.00
# 65781  ['loaded-dataset', '/lus/eagle/projects/tpc/br...       0.18
#
#          start_unix      end_unix
# 0      1.713091e+09  1.713091e+09
# 1      1.713091e+09  1.713091e+09
# 2      1.713091e+09  1.713091e+09
# 3      1.713091e+09  1.713091e+09
# 4      1.713091e+09  1.713091e+09
# ...             ...           ...
# 65777  1.713111e+09  1.713111e+09
# 65778  1.713111e+09  1.713111e+09
# 65779  1.713111e+09  1.713111e+09
# 65780  1.713111e+09  1.713111e+09
# 65781  1.713111e+09  1.713111e+09
#
# [65782 rows x 4 columns]
# scaling/semantic-chunking-polaris/nougat.sfr-mistral.polaris.nodes64.csv
# 1713110777.33
# {'total_runtime': 2655130.23, 'total_finished_tasks': 12849, 'total_data_processed': 1194957, 'throughput_performance': 60.47992930473053}
#                                                     tags  elapsed_s  \
# 0      ['loaded-encoder', '/lus/eagle/projects/tpc/br...      77.24
# 1      ['loaded-dataset', '/lus/eagle/projects/tpc/br...       0.19
# 2      ['loaded-encoder', '/lus/eagle/projects/tpc/br...      77.02
# 3      ['loaded-dataset', '/lus/eagle/projects/tpc/br...       0.19
# 4      ['loaded-encoder', '/lus/eagle/projects/tpc/br...      77.24
# ...                                                  ...        ...
# 29179  ['computed-embeddings', '/lus/eagle/projects/t...     202.45
# 29180  ['wrote-embeddings', '/lus/eagle/projects/tpc/...       0.14
# 29181  ['finished-embedding', '/lus/eagle/projects/tp...     202.75
# 29182  ['loaded-encoder', '/lus/eagle/projects/tpc/br...       0.00
# 29183  ['loaded-dataset', '/lus/eagle/projects/tpc/br...       0.18
#
#          start_unix      end_unix
# 0      1.713114e+09  1.713114e+09
# 1      1.713114e+09  1.713114e+09
# 2      1.713114e+09  1.713114e+09
# 3      1.713114e+09  1.713114e+09
# 4      1.713114e+09  1.713114e+09
# ...             ...           ...
# 29179  1.713116e+09  1.713117e+09
# 29180  1.713117e+09  1.713117e+09
# 29181  1.713116e+09  1.713117e+09
# 29182  1.713117e+09  1.713117e+09
# 29183  1.713117e+09  1.713117e+09
#
# [29184 rows x 4 columns]
# scaling/semantic-chunking-polaris/nougat.sfr-mistral.polaris.nodes128.csv
# 1713116600.11
# {'total_runtime': 1192626.37, 'total_finished_tasks': 5632, 'total_data_processed': 523776, 'throughput_performance': 216.2272843690642}
#                                                     tags  elapsed_s  \
# 0      ['loaded-encoder', '/lus/eagle/projects/tpc/br...     114.63
# 1      ['loaded-dataset', '/lus/eagle/projects/tpc/br...       0.20
# 2      ['loaded-encoder', '/lus/eagle/projects/tpc/br...     114.65
# 3      ['loaded-dataset', '/lus/eagle/projects/tpc/br...       0.20
# 4      ['loaded-encoder', '/lus/eagle/projects/tpc/br...     114.60
# ...                                                  ...        ...
# 54440  ['computed-embeddings', '/lus/eagle/projects/t...     198.96
# 54441  ['computed-embeddings', '/lus/eagle/projects/t...     197.50
# 54442  ['computed-embeddings', '/lus/eagle/projects/t...     198.12
# 54443  ['computed-embeddings', '/lus/eagle/projects/t...     198.04
# 54444  ['computed-embeddings', '/lus/eagle/projects/t...     197.21
#
#          start_unix      end_unix
# 0      1.713130e+09  1.713130e+09
# 1      1.713130e+09  1.713130e+09
# 2      1.713130e+09  1.713130e+09
# 3      1.713130e+09  1.713130e+09
# 4      1.713130e+09  1.713130e+09
# ...             ...           ...
# 54440  1.713132e+09  1.713132e+09
# 54441  1.713132e+09  1.713132e+09
# 54442  1.713132e+09  1.713132e+09
# 54443  1.713132e+09  1.713132e+09
# 54444  1.713132e+09  1.713132e+09
#
# [54445 rows x 4 columns]
# scaling/semantic-chunking-polaris/nougat.sfr-mistral.polaris.nodes256.csv
# 1713132140.03
# {'total_runtime': 2468887.05, 'total_finished_tasks': 10474, 'total_data_processed': 974082, 'throughput_performance': 385.7399127971086}
#                                                   tags  elapsed_s  \
# 0    ['loaded-encoder', '/lus/gila/projects/candle_...      18.39
# 1    ['loaded-dataset', '/lus/gila/projects/candle_...       0.10
# 2    ['loaded-encoder', '/lus/gila/projects/candle_...      19.11
# 3    ['loaded-dataset', '/lus/gila/projects/candle_...       0.11
# 4    ['loaded-encoder', '/lus/gila/projects/candle_...      27.58
# ..                                                 ...        ...
# 324  ['computed-embeddings', '/lus/gila/projects/ca...     251.99
# 325  ['wrote-embeddings', '/lus/gila/projects/candl...       0.11
# 326  ['finished-embedding', '/lus/gila/projects/can...     252.21
# 327  ['loaded-encoder', '/lus/gila/projects/candle_...       0.00
# 328  ['loaded-dataset', '/lus/gila/projects/candle_...       0.11
#
#        start_unix      end_unix
# 0    1.713149e+09  1.713149e+09
# 1    1.713149e+09  1.713149e+09
# 2    1.713149e+09  1.713149e+09
# 3    1.713149e+09  1.713149e+09
# 4    1.713149e+09  1.713149e+09
# ..            ...           ...
# 324  1.713150e+09  1.713150e+09
# 325  1.713150e+09  1.713150e+09
# 326  1.713150e+09  1.713150e+09
# 327  1.713150e+09  1.713150e+09
# 328  1.713150e+09  1.713150e+09
#
# [329 rows x 4 columns]
# scaling/semantic-chunking-sunspot/nougat.sfr-mistral.sunspot.nodes1.csv
# 1713150446.99
# {'total_runtime': 16552.25, 'total_finished_tasks': 61, 'total_data_processed': 5673, 'throughput_performance': 3.6266581428799745}
#                                                    tags  elapsed_s  \
# 0     ['loaded-encoder', '/lus/gila/projects/candle_...      25.30
# 1     ['loaded-dataset', '/lus/gila/projects/candle_...       0.15
# 2     ['loaded-encoder', '/lus/gila/projects/candle_...      36.48
# 3     ['loaded-dataset', '/lus/gila/projects/candle_...       0.15
# 4     ['loaded-encoder', '/lus/gila/projects/candle_...      37.60
# ...                                                 ...        ...
# 2267  ['wrote-embeddings', '/lus/gila/projects/candl...       0.09
# 2268  ['finished-embedding', '/lus/gila/projects/can...     260.95
# 2269  ['loaded-encoder', '/lus/gila/projects/candle_...       0.00
# 2270  ['loaded-dataset', '/lus/gila/projects/candle_...       0.11
# 2271  ['computed-embeddings', '/lus/gila/projects/ca...     263.31
#
#         start_unix      end_unix
# 0     1.713151e+09  1.713151e+09
# 1     1.713151e+09  1.713151e+09
# 2     1.713151e+09  1.713151e+09
# 3     1.713151e+09  1.713151e+09
# 4     1.713151e+09  1.713151e+09
# ...            ...           ...
# 2267  1.713153e+09  1.713153e+09
# 2268  1.713153e+09  1.713153e+09
# 2269  1.713153e+09  1.713153e+09
# 2270  1.713153e+09  1.713153e+09
# 2271  1.713153e+09  1.713153e+09
#
# [2272 rows x 4 columns]
# scaling/semantic-chunking-sunspot/nougat.sfr-mistral.sunspot.nodes4.csv
# 1713153215.87
# {'total_runtime': 123250.09, 'total_finished_tasks': 435, 'total_data_processed': 40455, 'throughput_performance': 15.068778891689705}
#                                                    tags  elapsed_s  \
# 0     ['loaded-encoder', '/lus/gila/projects/candle_...     277.42
# 1     ['loaded-dataset', '/lus/gila/projects/candle_...       0.08
# 2     ['loaded-encoder', '/lus/gila/projects/candle_...     279.53
# 3     ['loaded-dataset', '/lus/gila/projects/candle_...       0.08
# 4     ['loaded-encoder', '/lus/gila/projects/candle_...     279.50
# ...                                                 ...        ...
# 7329  ['computed-embeddings', '/lus/gila/projects/ca...     259.65
# 7330  ['wrote-embeddings', '/lus/gila/projects/candl...       0.11
# 7331  ['finished-embedding', '/lus/gila/projects/can...     259.87
# 7332  ['loaded-encoder', '/lus/gila/projects/candle_...       0.00
# 7333  ['loaded-dataset', '/lus/gila/projects/candle_...       0.11
#
#         start_unix      end_unix
# 0     1.713158e+09  1.713158e+09
# 1     1.713158e+09  1.713158e+09
# 2     1.713158e+09  1.713158e+09
# 3     1.713158e+09  1.713158e+09
# 4     1.713158e+09  1.713158e+09
# ...            ...           ...
# 7329  1.713160e+09  1.713160e+09
# 7330  1.713160e+09  1.713160e+09
# 7331  1.713160e+09  1.713160e+09
# 7332  1.713160e+09  1.713160e+09
# 7333  1.713160e+09  1.713160e+09
#
# [7334 rows x 4 columns]
# scaling/semantic-chunking-sunspot/nougat.sfr-mistral.sunspot.nodes16.csv
# 1713159999.24
# {'total_runtime': 424226.14999999997, 'total_finished_tasks': 1390, 'total_data_processed': 129270, 'throughput_performance': 54.18717146623603}
#                                                     tags  elapsed_s  \
# 0      ['loaded-encoder', '/lus/gila/projects/candle_...      36.69
# 1      ['loaded-dataset', '/lus/gila/projects/candle_...       0.12
# 2      ['loaded-encoder', '/lus/gila/projects/candle_...      42.41
# 3      ['loaded-dataset', '/lus/gila/projects/candle_...       0.15
# 4      ['loaded-encoder', '/lus/gila/projects/candle_...      51.54
# ...                                                  ...        ...
# 25601  ['computed-embeddings', '/lus/gila/projects/ca...     287.29
# 25602  ['wrote-embeddings', '/lus/gila/projects/candl...       0.08
# 25603  ['finished-embedding', '/lus/gila/projects/can...     333.60
# 25604  ['loaded-encoder', '/lus/gila/projects/candle_...       0.00
# 25605  ['loaded-dataset', '/lus/gila/projects/candle_...       0.11
#
#          start_unix      end_unix
# 0      1.713161e+09  1.713161e+09
# 1      1.713161e+09  1.713161e+09
# 2      1.713161e+09  1.713161e+09
# 3      1.713161e+09  1.713161e+09
# 4      1.713161e+09  1.713161e+09
# ...             ...           ...
# 25601  1.713165e+09  1.713165e+09
# 25602  1.713165e+09  1.713165e+09
# 25603  1.713165e+09  1.713165e+09
# 25604  1.713165e+09  1.713165e+09
# 25605  1.713165e+09  1.713165e+09
#
# [25606 rows x 4 columns]
# scaling/semantic-chunking-sunspot/nougat.sfr-mistral.sunspot.nodes32.csv
# 1713165357.16
# {'total_runtime': 1383343.4200000002, 'total_finished_tasks': 4814, 'total_data_processed': 447702, 'throughput_performance': 110.1097895689578}
#                                                     tags  elapsed_s  \
# 0      ['loaded-encoder', '/lus/gila/projects/candle_...     523.30
# 1      ['loaded-dataset', '/lus/gila/projects/candle_...       0.11
# 2      ['loaded-encoder', '/lus/gila/projects/candle_...     523.13
# 3      ['loaded-dataset', '/lus/gila/projects/candle_...       0.11
# 4      ['loaded-encoder', '/lus/gila/projects/candle_...     523.08
# ...                                                  ...        ...
# 60704  ['computed-embeddings', '/lus/gila/projects/ca...     257.88
# 60705  ['computed-embeddings', '/lus/gila/projects/ca...     258.80
# 60706  ['computed-embeddings', '/lus/gila/projects/ca...     259.62
# 60707  ['computed-embeddings', '/lus/gila/projects/ca...     260.13
# 60708  ['computed-embeddings', '/lus/gila/projects/ca...     259.21
#
#          start_unix      end_unix
# 0      1.713201e+09  1.713202e+09
# 1      1.713202e+09  1.713202e+09
# 2      1.713201e+09  1.713202e+09
# 3      1.713202e+09  1.713202e+09
# 4      1.713201e+09  1.713202e+09
# ...             ...           ...
# 60704  1.713204e+09  1.713204e+09
# 60705  1.713204e+09  1.713204e+09
# 60706  1.713204e+09  1.713204e+09
# 60707  1.713204e+09  1.713204e+09
# 60708  1.713204e+09  1.713204e+09
#
# [60709 rows x 4 columns]
# scaling/semantic-chunking-sunspot/nougat.sfr-mistral.sunspot.nodes96.csv
# 1713204458.6
# {'total_runtime': 3691107.2699999996, 'total_finished_tasks': 11672, 'total_data_processed': 1085496, 'throughput_performance': 319.876940484075}
# Polaris Semantic Chunking Throughput: [3.2093865931453514, 45.565247494383144, 60.47992930473053, 216.2272843690642, 385.7399127971086]
# Sunspot Semantic Chunking Throughput: [3.6266581428799745, 15.068778891689705, 54.18717146623603, 110.1097895689578, 319.876940484075]
# /var/folders/74/4jdnr7zn79q0h8cj7fy26vjm0000gn/T/ipykernel_47408/3899384454.py:66: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
polaris_oreo = [
    "scaling/pdfparsing-polaris/oreo.polaris.nodes2.csv",
    # "scaling/pdfparsing-polaris/oreo.polaris.nodes8.csv",
    "scaling/pdfparsing-polaris/oreo.polaris.nodes32.csv",
    "scaling/pdfparsing-polaris/oreo.polaris.nodes64.csv",
    "scaling/pdfparsing-polaris/oreo.polaris.nodes128.csv",
    "scaling/pdfparsing-polaris/oreo.polaris.nodes256.csv",
]


polaris_nougat = [
    "scaling/pdfparsing-polaris/nougat.polaris.nodes2.csv",
    # "scaling/pdfparsing-polaris/nougat.polaris.nodes8.csv",
    "scaling/pdfparsing-polaris/nougat.polaris.nodes32.csv",
    "scaling/pdfparsing-polaris/nougat.polaris.nodes64.csv",
    "scaling/pdfparsing-polaris/nougat.polaris.nodes128.csv",
    "scaling/pdfparsing-polaris/nougat.polaris.nodes256.csv",
]

sunspot_nougat = [
    "scaling/pdfparsing-sunspot/nougat.sunspot.nodes1.csv",
    "scaling/pdfparsing-sunspot/nougat.sunspot.nodes2.csv",
    "scaling/pdfparsing-sunspot/nougat.sunspot.nodes4.csv",
    "scaling/pdfparsing-sunspot/nougat.sunspot.nodes8.csv",
    "scaling/pdfparsing-sunspot/nougat.sunspot.nodes16.csv",
    "scaling/pdfparsing-sunspot/nougat.sunspot.nodes32.csv",
    "scaling/pdfparsing-sunspot/nougat.sunspot.nodes64.csv",
    "scaling/pdfparsing-sunspot/nougat.sunspot.nodes96.csv",
]

polaris_oreo_throughput = [
    compute_throughput_performance(file, "finished-parsing", 10)[
        "throughput_performance"
    ]
    for file in polaris_oreo
]

polaris_nougat_throughput = [
    compute_throughput_performance(file, "finished-parsing", 10)[
        "throughput_performance"
    ]
    for file in polaris_nougat
]

sunspot_nougat_throughput = [
    compute_throughput_performance(file, "finished-parsing", 10)[
        "throughput_performance"
    ]
    for file in sunspot_nougat
]

polaris_oreo_ngpus = [2 * 4, 32 * 4, 64 * 4, 128 * 4, 256 * 4]
polaris_nougat_ngpus = [2 * 4, 32 * 4, 64 * 4, 128 * 4, 256 * 4]
sunspot_ngpus = [
    1 * 12,
    2 * 12,
    4 * 12,
    8 * 12,
    16 * 12,
    32 * 12,
    64 * 12,
    96 * 12,
]

x_values = [polaris_oreo_ngpus, polaris_nougat_ngpus, sunspot_ngpus]
y_values = [
    polaris_oreo_throughput,
    polaris_nougat_throughput,
    sunspot_nougat_throughput,
]
labels = ["Polaris Oreo", "Polaris Nougat", "Sunspot Nougat"]
image_name = "scaling_relations_pdfparsing-big-font.pdf"
plot_scaling_relations(x_values, y_values, labels, image_name)

print("Polaris Oreo Throughout: ", polaris_oreo_throughput)
print("Polaris Nougat Throughout: ", polaris_nougat_throughput)
print("Sunspot Nougat Throughout: ", sunspot_nougat_throughput)
# Out:
#                                                   tags  elapsed_s  \
# 0    ['initialize-parser', '2a2f70d5-03bf-46ab-a71d...     144.50
# 1    ['initialize-parser', '9c8a8392-0dd6-456e-90be...     144.12
# 2    ['initialize-parser', '32c44aea-13ef-4199-ad3c...     144.40
# 3    ['initialize-parser', '47982988-ecdc-4573-a98c...     144.19
# 4    ['initialize-parser', 'b08e83e6-0254-4e20-b8b0...     144.12
# ..                                                 ...        ...
# 443  ['parser-parse', '50bac34d-a26e-4f22-9ba6-363b...      56.82
# 444  ['write-jsonl', '50bac34d-a26e-4f22-9ba6-363b6...       0.00
# 445  ['parse-pdfs', '/lus/eagle/projects/tpc/bracea...      56.83
# 446  ['finished-parsing', '/lus/eagle/projects/tpc/...      58.33
# 447  ['initialize-parser', '877ef0ae-a665-4786-8de3...       0.00
#
#        start_unix      end_unix
# 0    1.713122e+09  1.713122e+09
# 1    1.713122e+09  1.713122e+09
# 2    1.713122e+09  1.713122e+09
# 3    1.713122e+09  1.713122e+09
# 4    1.713122e+09  1.713122e+09
# ..            ...           ...
# 443  1.713122e+09  1.713122e+09
# 444  1.713122e+09  1.713122e+09
# 445  1.713122e+09  1.713122e+09
# 446  1.713122e+09  1.713122e+09
# 447  1.713122e+09  1.713122e+09
#
# [448 rows x 4 columns]
# scaling/pdfparsing-polaris/oreo.polaris.nodes2.csv
# 1713122482.56
# {'total_runtime': 6384.469999999999, 'total_finished_tasks': 88, 'total_data_processed': 880, 'throughput_performance': 1.0903774193522067}
#                                                     tags  elapsed_s  \
# 0      ['initialize-parser', 'cb16f9c5-1c00-483d-ac40...      31.02
# 1      ['initialize-parser', 'fe946e4a-0494-465c-80f5...      31.07
# 2      ['initialize-parser', 'a1e72ad6-a7e8-4c70-a0a9...      31.60
# 3      ['initialize-parser', 'e6c8b6b9-4856-4385-a4d7...      31.62
# 4      ['initialize-parser', '10b97a87-b67e-467c-9513...      30.28
# ...                                                  ...        ...
# 17438  ['parser-parse', '8d324f40-779d-4afd-9388-403b...      56.03
# 17439  ['write-jsonl', '8d324f40-779d-4afd-9388-403b1...       0.00
# 17440  ['parse-pdfs', '/lus/eagle/projects/tpc/bracea...      56.03
# 17441  ['finished-parsing', '/lus/eagle/projects/tpc/...      57.59
# 17442  ['initialize-parser', '980bbc60-7f07-41f5-803d...       0.00
#
#          start_unix      end_unix
# 0      1.713123e+09  1.713123e+09
# 1      1.713123e+09  1.713123e+09
# 2      1.713123e+09  1.713123e+09
# 3      1.713123e+09  1.713123e+09
# 4      1.713123e+09  1.713123e+09
# ...             ...           ...
# 17438  1.713124e+09  1.713124e+09
# 17439  1.713124e+09  1.713124e+09
# 17440  1.713124e+09  1.713124e+09
# 17441  1.713124e+09  1.713124e+09
# 17442  1.713124e+09  1.713124e+09
#
# [17443 rows x 4 columns]
# scaling/pdfparsing-polaris/oreo.polaris.nodes32.csv
# 1713124436.86
# {'total_runtime': 217885.52000000002, 'total_finished_tasks': 3463, 'total_data_processed': 34630, 'throughput_performance': 19.43005908171016}
#                                                     tags  elapsed_s  \
# 0      ['initialize-parser', 'f0f0a721-40e0-45db-8e06...     194.29
# 1      ['initialize-parser', '95bf594e-52d5-46ce-bfbe...     193.87
# 2      ['initialize-parser', 'd2d88607-6518-474e-8bcd...     194.06
# 3      ['initialize-parser', '8885243d-e7a1-4ef6-a6e2...     193.91
# 4      ['initialize-parser', '81e8ce96-9faf-4e58-9e8e...     194.20
# ...                                                  ...        ...
# 14371  ['parser-parse', 'ff1bf7e0-485d-4e4b-9035-c8c3...      55.06
# 14372  ['write-jsonl', 'ff1bf7e0-485d-4e4b-9035-c8c38...       0.00
# 14373  ['parse-pdfs', '/lus/eagle/projects/tpc/bracea...      55.07
# 14374  ['finished-parsing', '/lus/eagle/projects/tpc/...      56.58
# 14375  ['initialize-parser', '1ead51ff-a710-4ac5-9b57...       0.00
#
#          start_unix      end_unix
# 0      1.713125e+09  1.713125e+09
# 1      1.713125e+09  1.713125e+09
# 2      1.713125e+09  1.713125e+09
# 3      1.713125e+09  1.713125e+09
# 4      1.713125e+09  1.713125e+09
# ...             ...           ...
# 14371  1.713126e+09  1.713126e+09
# 14372  1.713126e+09  1.713126e+09
# 14373  1.713126e+09  1.713126e+09
# 14374  1.713126e+09  1.713126e+09
# 14375  1.713126e+09  1.713126e+09
#
# [14376 rows x 4 columns]
# scaling/pdfparsing-polaris/oreo.polaris.nodes64.csv
# 1713125740.68
# {'total_runtime': 214981.46, 'total_finished_tasks': 2824, 'total_data_processed': 28240, 'throughput_performance': 32.67610848802228}
#                                                     tags  elapsed_s  \
# 0      ['initialize-parser', '2c2ad539-d155-4fcb-be9c...      29.93
# 1      ['initialize-parser', '3a170edf-dc12-4eca-83c0...      30.10
# 2      ['initialize-parser', 'f97df0ce-0b62-4c04-a4d4...      30.12
# 3      ['initialize-parser', 'cf3e57e8-9b59-475b-909c...      30.11
# 4      ['initialize-parser', '261cfd02-df6c-4353-978a...      30.97
# ...                                                  ...        ...
# 44447  ['parser-parse', '1e6cce05-3f39-437f-8708-0ec9...      53.67
# 44448  ['write-jsonl', '1e6cce05-3f39-437f-8708-0ec91...       0.00
# 44449  ['parse-pdfs', '/lus/eagle/projects/tpc/bracea...      53.67
# 44450  ['finished-parsing', '/lus/eagle/projects/tpc/...      55.17
# 44451  ['initialize-parser', 'c5763cdb-2cdc-41ce-b331...       0.00
#
#          start_unix      end_unix
# 0      1.713126e+09  1.713126e+09
# 1      1.713126e+09  1.713126e+09
# 2      1.713126e+09  1.713126e+09
# 3      1.713126e+09  1.713126e+09
# 4      1.713126e+09  1.713126e+09
# ...             ...           ...
# 44447  1.713127e+09  1.713127e+09
# 44448  1.713127e+09  1.713127e+09
# 44449  1.713127e+09  1.713127e+09
# 44450  1.713127e+09  1.713127e+09
# 44451  1.713127e+09  1.713127e+09
#
# [44452 rows x 4 columns]
# scaling/pdfparsing-polaris/oreo.polaris.nodes128.csv
# 1713127021.35
# {'total_runtime': 558659.78, 'total_finished_tasks': 8788, 'total_data_processed': 87880, 'throughput_performance': 76.1908064818994}
#                                                     tags  elapsed_s  \
# 0      ['initialize-parser', 'd4b2da7f-44b9-4b28-b728...      70.02
# 1      ['initialize-parser', '7567d737-a198-4cbf-bb78...      70.30
# 2      ['initialize-parser', '9c444ecf-3232-48d1-81c2...      70.00
# 3      ['initialize-parser', '292b5909-f409-4d6c-8b9a...      70.26
# 4      ['initialize-parser', '80e2466b-8259-4d56-9526...      70.06
# ...                                                  ...        ...
# 41334  ['parser-parse', 'eb66e86b-0baa-4144-9c49-579e...      54.78
# 41335  ['write-jsonl', 'eb66e86b-0baa-4144-9c49-579ef...       0.00
# 41336  ['parse-pdfs', '/lus/eagle/projects/tpc/bracea...      54.78
# 41337  ['finished-parsing', '/lus/eagle/projects/tpc/...      56.32
# 41338  ['initialize-parser', '74bb0945-0518-4725-9e80...       0.00
#
#          start_unix      end_unix
# 0      1.713132e+09  1.713132e+09
# 1      1.713132e+09  1.713132e+09
# 2      1.713132e+09  1.713132e+09
# 3      1.713132e+09  1.713132e+09
# 4      1.713132e+09  1.713132e+09
# ...             ...           ...
# 41334  1.713133e+09  1.713133e+09
# 41335  1.713133e+09  1.713133e+09
# 41336  1.713133e+09  1.713133e+09
# 41337  1.713133e+09  1.713133e+09
# 41338  1.713133e+09  1.713133e+09
#
# [41339 rows x 4 columns]
# scaling/pdfparsing-polaris/oreo.polaris.nodes256.csv
# 1713132907.74
# {'total_runtime': 647697.1599999999, 'total_finished_tasks': 8063, 'total_data_processed': 80630, 'throughput_performance': 118.23620845416674}
#                                                   tags  elapsed_s  \
# 0    ['initialize-parser', '8c03d80c-8e7b-413d-91c0...      95.26
# 1    ['initialize-parser', '73611e6b-30d4-4d47-9dd7...      95.13
# 2    ['initialize-parser', '6c33e7ca-bcfa-499b-bfa8...      95.06
# 3    ['initialize-parser', '9753b756-5e52-48dd-8d67...      95.47
# 4    ['initialize-parser', 'cad9e21a-68c1-4654-9e35...      95.20
# ..                                                 ...        ...
# 208  ['parser-parse', 'b261663c-f1a1-4b3b-857d-d8f9...     196.37
# 209  ['write-jsonl', 'b261663c-f1a1-4b3b-857d-d8f91...       0.00
# 210  ['parse-pdfs', '/lus/eagle/projects/tpc/bracea...     196.38
# 211  ['finished-parsing', '/lus/eagle/projects/tpc/...     198.09
# 212  ['initialize-parser', 'a1de3445-ac36-4f53-993b...       0.00
#
#        start_unix      end_unix
# 0    1.713075e+09  1.713075e+09
# 1    1.713075e+09  1.713075e+09
# 2    1.713075e+09  1.713075e+09
# 3    1.713075e+09  1.713075e+09
# 4    1.713075e+09  1.713075e+09
# ..            ...           ...
# 208  1.713076e+09  1.713077e+09
# 209  1.713077e+09  1.713077e+09
# 210  1.713076e+09  1.713077e+09
# 211  1.713076e+09  1.713077e+09
# 212  1.713077e+09  1.713077e+09
#
# [213 rows x 4 columns]
# scaling/pdfparsing-polaris/nougat.polaris.nodes2.csv
# 1713076624.55
# {'total_runtime': 9342.39, 'total_finished_tasks': 41, 'total_data_processed': 410, 'throughput_performance': 0.31281233547375864}
#                                                    tags  elapsed_s  \
# 0     ['initialize-parser', '63fcfe05-41fe-4738-872f...       6.93
# 1     ['initialize-parser', '4b2620c3-1b30-47d5-b082...       6.93
# 2     ['initialize-parser', '9d781fa1-f427-4561-a5e4...       6.93
# 3     ['initialize-parser', '2a9d1c74-80f0-4c26-85e3...       7.03
# 4     ['initialize-parser', 'ae754266-9476-4a47-ae2c...       7.02
# ...                                                 ...        ...
# 3463  ['parser-parse', 'd228d0a4-c8be-4015-98f0-1306...     225.58
# 3464  ['write-jsonl', 'd228d0a4-c8be-4015-98f0-1306b...       0.02
# 3465  ['parse-pdfs', '/lus/eagle/projects/tpc/bracea...     225.59
# 3466  ['finished-parsing', '/lus/eagle/projects/tpc/...     227.11
# 3467  ['initialize-parser', '232c6ef3-0d74-4500-9888...       0.00
#
#         start_unix      end_unix
# 0     1.713078e+09  1.713078e+09
# 1     1.713078e+09  1.713078e+09
# 2     1.713078e+09  1.713078e+09
# 3     1.713078e+09  1.713078e+09
# 4     1.713078e+09  1.713078e+09
# ...            ...           ...
# 3463  1.713080e+09  1.713080e+09
# 3464  1.713080e+09  1.713080e+09
# 3465  1.713080e+09  1.713080e+09
# 3466  1.713080e+09  1.713080e+09
# 3467  1.713080e+09  1.713080e+09
#
# [3468 rows x 4 columns]
# scaling/pdfparsing-polaris/nougat.polaris.nodes32.csv
# 1713079786.27
# {'total_runtime': 155615.49, 'total_finished_tasks': 668, 'total_data_processed': 6680, 'throughput_performance': 5.024898825484794}
#                                                    tags  elapsed_s  \
# 0     ['initialize-parser', '80c2ae85-bbcf-436e-91d8...     119.48
# 1     ['initialize-parser', '3a845310-2acf-4166-89a7...     119.67
# 2     ['initialize-parser', 'af99b4a7-3c94-484e-a474...     119.34
# 3     ['initialize-parser', '177aa4ab-36bc-4727-af7d...     119.65
# 4     ['initialize-parser', '7f0e2224-7790-4e92-aa4f...     120.14
# ...                                                 ...        ...
# 7941  ['parser-parse', 'd5978611-c235-433a-8e06-0ce9...     230.49
# 7942  ['write-jsonl', 'd5978611-c235-433a-8e06-0ce9b...       0.01
# 7943  ['parse-pdfs', '/lus/eagle/projects/tpc/bracea...     230.49
# 7944  ['finished-parsing', '/lus/eagle/projects/tpc/...     232.04
# 7945  ['initialize-parser', '15ba4b45-b551-4371-9d4b...       0.00
#
#         start_unix      end_unix
# 0     1.713080e+09  1.713080e+09
# 1     1.713080e+09  1.713080e+09
# 2     1.713080e+09  1.713080e+09
# 3     1.713080e+09  1.713080e+09
# 4     1.713080e+09  1.713080e+09
# ...            ...           ...
# 7941  1.713082e+09  1.713082e+09
# 7942  1.713082e+09  1.713082e+09
# 7943  1.713082e+09  1.713082e+09
# 7944  1.713082e+09  1.713082e+09
# 7945  1.713082e+09  1.713082e+09
#
# [7946 rows x 4 columns]
# scaling/pdfparsing-polaris/nougat.polaris.nodes64.csv
# 1713081894.42
# {'total_runtime': 364849.18, 'total_finished_tasks': 1538, 'total_data_processed': 15380, 'throughput_performance': 10.039754293097037}
#                                                     tags  elapsed_s  \
# 0      ['initialize-parser', 'cfb29717-16f0-4c95-983c...     151.66
# 1      ['initialize-parser', '84b45517-52c5-4393-94b4...     151.74
# 2      ['initialize-parser', '9624bf8f-6608-402d-be09...     151.35
# 3      ['initialize-parser', '3d61dd54-ce58-4780-acb2...     151.66
# 4      ['initialize-parser', 'd639d12e-c430-49a6-b088...     152.89
# ...                                                  ...        ...
# 79744  ['parser-parse', 'a302b34d-428f-4c9e-959b-b4ed...     195.69
# 79745  ['write-jsonl', 'a302b34d-428f-4c9e-959b-b4ed1...       0.00
# 79746  ['parse-pdfs', '/lus/eagle/projects/tpc/bracea...     195.70
# 79747  ['finished-parsing', '/lus/eagle/projects/tpc/...     197.20
# 79748  ['initialize-parser', 'b7ee9955-6da8-4c4e-9ac0...       0.00
#
#          start_unix      end_unix
# 0      1.713089e+09  1.713089e+09
# 1      1.713089e+09  1.713089e+09
# 2      1.713089e+09  1.713089e+09
# 3      1.713089e+09  1.713089e+09
# 4      1.713089e+09  1.713089e+09
# ...             ...           ...
# 79744  1.713107e+09  1.713107e+09
# 79745  1.713107e+09  1.713107e+09
# 79746  1.713107e+09  1.713107e+09
# 79747  1.713107e+09  1.713107e+09
# 79748  1.713107e+09  1.713107e+09
#
# [79749 rows x 4 columns]
# scaling/pdfparsing-polaris/nougat.polaris.nodes128.csv
# 1713107107.69
# {'total_runtime': 3535328.5999999996, 'total_finished_tasks': 15745, 'total_data_processed': 157450, 'throughput_performance': 8.700510149900053}
#                                                     tags  elapsed_s  \
# 0      ['initialize-parser', 'af3eee34-f87b-4579-94c3...     178.92
# 1      ['initialize-parser', '4879c88c-893e-4397-a44e...     179.38
# 2      ['initialize-parser', '7d167ca0-2058-4e06-9257...     179.41
# 3      ['initialize-parser', '8d4dce8d-29b0-4d23-aaf4...     178.88
# 4      ['initialize-parser', '0cd46798-3191-4681-ba01...     179.47
# ...                                                  ...        ...
# 40979  ['parser-parse', '779c8a8f-35b9-4702-8cf4-3853...     215.75
# 40980  ['write-jsonl', '779c8a8f-35b9-4702-8cf4-3853f...       0.02
# 40981  ['parse-pdfs', '/lus/eagle/projects/tpc/bracea...     215.77
# 40982  ['finished-parsing', '/lus/eagle/projects/tpc/...     217.44
# 40983  ['initialize-parser', 'b4476487-8a5a-4e3b-ba8f...       0.00
#
#          start_unix      end_unix
# 0      1.713112e+09  1.713112e+09
# 1      1.713112e+09  1.713112e+09
# 2      1.713112e+09  1.713112e+09
# 3      1.713112e+09  1.713112e+09
# 4      1.713112e+09  1.713112e+09
# ...             ...           ...
# 40979  1.713114e+09  1.713114e+09
# 40980  1.713114e+09  1.713114e+09
# 40981  1.713114e+09  1.713114e+09
# 40982  1.713114e+09  1.713114e+09
# 40983  1.713114e+09  1.713114e+09
#
# [40984 rows x 4 columns]
# scaling/pdfparsing-polaris/nougat.polaris.nodes256.csv
# 1713114112.04
# {'total_runtime': 2000096.1600000001, 'total_finished_tasks': 7992, 'total_data_processed': 79920, 'throughput_performance': 38.90641430362613}
#                                                   tags  elapsed_s  \
# 0    ['initialize-parser', 'ce6733e1-687c-400d-909b...      79.22
# 1    ['initialize-parser', 'b4c9db16-710a-4103-b5c7...      79.19
# 2    ['initialize-parser', 'acf81efc-be20-45c8-8266...      79.49
# 3    ['initialize-parser', 'a65d7bfa-7ac3-4c47-8359...      79.56
# 4    ['initialize-parser', '3a28add6-a300-4b94-93a8...      79.01
# ..                                                 ...        ...
# 542  ['parser-parse', '2872d176-d3df-46a2-83ac-17dd...     215.44
# 543  ['write-jsonl', '2872d176-d3df-46a2-83ac-17dd5...       0.00
# 544  ['parse-pdfs', '/lus/gila/projects/candle_aesp...     215.45
# 545  ['finished-parsing', '/lus/gila/projects/candl...     216.67
# 546  ['initialize-parser', 'ec901288-a992-44dd-8b0a...       0.00
#
#        start_unix      end_unix
# 0    1.713026e+09  1.713026e+09
# 1    1.713026e+09  1.713026e+09
# 2    1.713026e+09  1.713026e+09
# 3    1.713026e+09  1.713026e+09
# 4    1.713026e+09  1.713026e+09
# ..            ...           ...
# 542  1.713028e+09  1.713028e+09
# 543  1.713028e+09  1.713028e+09
# 544  1.713028e+09  1.713028e+09
# 545  1.713028e+09  1.713028e+09
# 546  1.713028e+09  1.713028e+09
#
# [547 rows x 4 columns]
# scaling/pdfparsing-sunspot/nougat.sunspot.nodes1.csv
# 1713027813.44
# {'total_runtime': 20116.57, 'total_finished_tasks': 107, 'total_data_processed': 1070, 'throughput_performance': 0.6056420938137749}
#                                                    tags  elapsed_s  \
# 0     ['initialize-parser', '49cfb476-36e3-4a8d-b947...      62.54
# 1     ['initialize-parser', '8c73e603-8bba-478f-a456...      62.52
# 2     ['initialize-parser', '347fd42e-4b7b-4325-a8be...      62.50
# 3     ['initialize-parser', '840500f0-12bb-49f2-b2d9...      62.52
# 4     ['initialize-parser', 'e6f1a8a9-256e-4c03-b40a...      62.57
# ...                                                 ...        ...
# 1104  ['parser-parse', '44adf27f-686e-44e4-8b7d-0258...     176.09
# 1105  ['write-jsonl', '44adf27f-686e-44e4-8b7d-02587...       0.00
# 1106  ['parse-pdfs', '/lus/gila/projects/candle_aesp...     176.09
# 1107  ['finished-parsing', '/lus/gila/projects/candl...     177.29
# 1108  ['initialize-parser', 'fa3adac9-c947-4a5c-a1f1...       0.00
#
#         start_unix      end_unix
# 0     1.713029e+09  1.713029e+09
# 1     1.713029e+09  1.713029e+09
# 2     1.713029e+09  1.713029e+09
# 3     1.713029e+09  1.713029e+09
# 4     1.713029e+09  1.713029e+09
# ...            ...           ...
# 1104  1.713030e+09  1.713031e+09
# 1105  1.713031e+09  1.713031e+09
# 1106  1.713030e+09  1.713031e+09
# 1107  1.713030e+09  1.713031e+09
# 1108  1.713031e+09  1.713031e+09
#
# [1109 rows x 4 columns]
# scaling/pdfparsing-sunspot/nougat.sunspot.nodes2.csv
# 1713030521.62
# {'total_runtime': 40541.29000000001, 'total_finished_tasks': 217, 'total_data_processed': 2170, 'throughput_performance': 1.2015836541594085}
#                                                    tags  elapsed_s  \
# 0     ['initialize-parser', '5162ac0d-15a4-4555-b934...     474.36
# 1     ['initialize-parser', 'f0c8d0ad-5408-43a4-a7b3...     479.50
# 2     ['initialize-parser', 'fd724894-fcf3-4845-a266...     474.58
# 3     ['initialize-parser', '6a7b85eb-58be-494e-9a87...     474.59
# 4     ['initialize-parser', 'd544f37f-14f3-41b2-ac96...     474.50
# ...                                                 ...        ...
# 1703  ['parser-parse', '6f60a7d8-d97b-4678-a2b4-7b7f...     184.41
# 1704  ['write-jsonl', '6f60a7d8-d97b-4678-a2b4-7b7f2...       0.00
# 1705  ['parse-pdfs', '/lus/gila/projects/candle_aesp...     184.42
# 1706  ['finished-parsing', '/lus/gila/projects/candl...     185.59
# 1707  ['initialize-parser', 'f8f3ecf1-f84a-4f6b-80ce...       0.00
#
#         start_unix      end_unix
# 0     1.713031e+09  1.713032e+09
# 1     1.713031e+09  1.713032e+09
# 2     1.713031e+09  1.713032e+09
# 3     1.713031e+09  1.713032e+09
# 4     1.713031e+09  1.713032e+09
# ...            ...           ...
# 1703  1.713033e+09  1.713033e+09
# 1704  1.713033e+09  1.713033e+09
# 1705  1.713033e+09  1.713033e+09
# 1706  1.713033e+09  1.713033e+09
# 1707  1.713033e+09  1.713033e+09
#
# [1708 rows x 4 columns]
# scaling/pdfparsing-sunspot/nougat.sunspot.nodes4.csv
# 1713032813.08
# {'total_runtime': 81752.51, 'total_finished_tasks': 332, 'total_data_processed': 3320, 'throughput_performance': 1.8883378078719442}
#                                                    tags  elapsed_s  \
# 0     ['initialize-parser', 'a81414a0-c6bb-4016-b958...       4.26
# 1     ['initialize-parser', 'b7ebbcba-ca62-407a-9441...       4.53
# 2     ['initialize-parser', '8815577c-dcf5-44da-bb43...       4.54
# 3     ['initialize-parser', '9352db90-1b19-4a6c-b38f...       5.02
# 4     ['initialize-parser', 'bd28b915-6b4d-4645-b4ce...       5.05
# ...                                                 ...        ...
# 4626  ['parser-parse', 'fe06e697-e437-48eb-8340-2068...     184.48
# 4627  ['write-jsonl', 'fe06e697-e437-48eb-8340-20687...       0.00
# 4628  ['parse-pdfs', '/lus/gila/projects/candle_aesp...     184.48
# 4629  ['finished-parsing', '/lus/gila/projects/candl...     185.80
# 4630  ['initialize-parser', '8d8292e1-b895-47c1-bca9...       0.00
#
#         start_unix      end_unix
# 0     1.713035e+09  1.713035e+09
# 1     1.713035e+09  1.713035e+09
# 2     1.713035e+09  1.713035e+09
# 3     1.713035e+09  1.713035e+09
# 4     1.713035e+09  1.713035e+09
# ...            ...           ...
# 4626  1.713037e+09  1.713037e+09
# 4627  1.713037e+09  1.713037e+09
# 4628  1.713037e+09  1.713037e+09
# 4629  1.713037e+09  1.713037e+09
# 4630  1.713037e+09  1.713037e+09
#
# [4631 rows x 4 columns]
# scaling/pdfparsing-sunspot/nougat.sunspot.nodes8.csv
# 1713036950.52
# {'total_runtime': 164750.33000000002, 'total_finished_tasks': 907, 'total_data_processed': 9070, 'throughput_performance': 5.004966339124459}
#                                                    tags  elapsed_s  \
# 0     ['initialize-parser', '7b3cc2e5-a38a-43c3-9e14...      75.80
# 1     ['initialize-parser', '41832623-7912-4035-be0d...      75.77
# 2     ['initialize-parser', '3e3ad0ff-105f-4ab9-8720...      76.38
# 3     ['initialize-parser', '63c1caa5-0642-463f-9ccb...      76.46
# 4     ['initialize-parser', 'f2dea602-31e0-431b-9884...      75.93
# ...                                                 ...        ...
# 8752  ['parser-parse', 'bc67d1e0-394b-4483-9821-7bb9...     174.84
# 8753  ['write-jsonl', 'bc67d1e0-394b-4483-9821-7bb92...       0.00
# 8754  ['parse-pdfs', '/lus/gila/projects/candle_aesp...     174.85
# 8755  ['finished-parsing', '/lus/gila/projects/candl...     176.04
# 8756  ['initialize-parser', '49acf7b8-0c3c-45da-82a3...       0.00
#
#         start_unix      end_unix
# 0     1.713038e+09  1.713038e+09
# 1     1.713038e+09  1.713038e+09
# 2     1.713038e+09  1.713038e+09
# 3     1.713038e+09  1.713038e+09
# 4     1.713038e+09  1.713038e+09
# ...            ...           ...
# 8752  1.713040e+09  1.713040e+09
# 8753  1.713040e+09  1.713040e+09
# 8754  1.713040e+09  1.713040e+09
# 8755  1.713040e+09  1.713040e+09
# 8756  1.713040e+09  1.713040e+09
#
# [8757 rows x 4 columns]
# scaling/pdfparsing-sunspot/nougat.sunspot.nodes16.csv
# 1713040223.39
# {'total_runtime': 324083.4199999999, 'total_finished_tasks': 1713, 'total_data_processed': 17130, 'throughput_performance': 9.485312439185861}
#                                                     tags  elapsed_s  \
# 0      ['initialize-parser', '6ad221ad-756c-4a7f-9e0d...      36.99
# 1      ['initialize-parser', '5a65c332-9245-4c56-b058...      36.75
# 2      ['initialize-parser', 'bb9b57e7-a9c0-4a2a-994b...      37.38
# 3      ['initialize-parser', '524c5648-5638-4ddb-b821...      36.80
# 4      ['initialize-parser', '8d75ddc5-fa7b-4442-8fd2...      37.24
# ...                                                  ...        ...
# 18128  ['initialize-parser', '0abbae18-e2cb-4623-a446...       6.28
# 18129  ['initialize-parser', 'cf7ac9a0-0652-4977-ad04...       6.13
# 18130  ['initialize-parser', '3d132c4c-a1cc-422e-9f5b...       6.40
# 18131  ['initialize-parser', '51feb230-fe19-4772-83b5...       6.36
# 18132  ['initialize-parser', '1f7b4967-f041-4a88-83f5...       5.78
#
#          start_unix      end_unix
# 0      1.713044e+09  1.713044e+09
# 1      1.713044e+09  1.713044e+09
# 2      1.713044e+09  1.713044e+09
# 3      1.713044e+09  1.713044e+09
# 4      1.713044e+09  1.713044e+09
# ...             ...           ...
# 18128  1.713046e+09  1.713046e+09
# 18129  1.713046e+09  1.713046e+09
# 18130  1.713046e+09  1.713046e+09
# 18131  1.713046e+09  1.713046e+09
# 18132  1.713046e+09  1.713046e+09
#
# [18133 rows x 4 columns]
# scaling/pdfparsing-sunspot/nougat.sunspot.nodes32.csv
# 1713046328.32
# {'total_runtime': 656866.35, 'total_finished_tasks': 3534, 'total_data_processed': 35340, 'throughput_performance': 18.350052963982698}
#                                                     tags  elapsed_s  \
# 0      ['initialize-parser', 'be68044f-adb4-4132-956c...      76.64
# 1      ['initialize-parser', 'ef93941c-f9c0-4083-833a...      76.51
# 2      ['initialize-parser', '19c2db3d-a94a-41cb-90e1...      75.27
# 3      ['initialize-parser', '566540b7-55c8-43d9-aeb9...      76.72
# 4      ['initialize-parser', 'fc455885-cddb-429c-abed...      76.32
# ...                                                  ...        ...
# 16923  ['parser-parse', '21e9a4c6-80ac-4c5b-974b-869c...     174.43
# 16924  ['write-jsonl', '21e9a4c6-80ac-4c5b-974b-869cc...       0.00
# 16925  ['parse-pdfs', '/lus/gila/projects/candle_aesp...     174.43
# 16926  ['finished-parsing', '/lus/gila/projects/candl...     175.45
# 16927  ['initialize-parser', 'fc22e48d-4543-4c63-81b9...       0.00
#
#          start_unix      end_unix
# 0      1.713051e+09  1.713051e+09
# 1      1.713051e+09  1.713051e+09
# 2      1.713051e+09  1.713051e+09
# 3      1.713051e+09  1.713051e+09
# 4      1.713051e+09  1.713051e+09
# ...             ...           ...
# 16923  1.713052e+09  1.713052e+09
# 16924  1.713052e+09  1.713052e+09
# 16925  1.713052e+09  1.713052e+09
# 16926  1.713052e+09  1.713052e+09
# 16927  1.713052e+09  1.713052e+09
#
# [16928 rows x 4 columns]
# scaling/pdfparsing-sunspot/nougat.sunspot.nodes64.csv
# 1713052342.27
# {'total_runtime': 702030.6699999999, 'total_finished_tasks': 3232, 'total_data_processed': 32320, 'throughput_performance': 32.10425937607427}
#                                                     tags  elapsed_s  \
# 0      ['initialize-parser', '1484d037-b8bc-434d-a864...      55.40
# 1      ['initialize-parser', '31690083-db43-44f6-88e8...      55.37
# 2      ['initialize-parser', '9baab1a5-1d3e-4d98-af7e...      55.29
# 3      ['initialize-parser', 'd9b422ac-4427-4541-bac8...      55.34
# 4      ['initialize-parser', '2a040043-1e7c-41b6-ac7a...      55.14
# ...                                                  ...        ...
# 15387  ['parser-parse', 'ba3978bf-08c7-47b9-b3d9-865a...     170.51
# 15388  ['write-jsonl', 'ba3978bf-08c7-47b9-b3d9-865ae...       0.66
# 15389  ['parse-pdfs', '/lus/gila/projects/candle_aesp...     171.17
# 15390  ['finished-parsing', '/lus/gila/projects/candl...     172.30
# 15391  ['initialize-parser', 'be8dc1b2-e9a3-4abf-8f65...       0.00
#
#          start_unix      end_unix
# 0      1.713083e+09  1.713084e+09
# 1      1.713083e+09  1.713084e+09
# 2      1.713083e+09  1.713084e+09
# 3      1.713083e+09  1.713084e+09
# 4      1.713083e+09  1.713084e+09
# ...             ...           ...
# 15387  1.713084e+09  1.713084e+09
# 15388  1.713084e+09  1.713084e+09
# 15389  1.713084e+09  1.713084e+09
# 15390  1.713084e+09  1.713084e+09
# 15391  1.713084e+09  1.713084e+09
#
# [15392 rows x 4 columns]
# scaling/pdfparsing-sunspot/nougat.sunspot.nodes96.csv
# 1713084263.73
# {'total_runtime': 778675.33, 'total_finished_tasks': 2848, 'total_data_processed': 28480, 'throughput_performance': 35.62003627252641}
# Polaris Oreo Throughout:  [1.0903774193522067, 19.43005908171016, 32.67610848802228, 76.1908064818994, 118.23620845416674]
# Polaris Nougat Throughout:  [0.31281233547375864, 5.024898825484794, 10.039754293097037, 8.700510149900053, 38.90641430362613]
# Sunspot Nougat Throughout:  [0.6056420938137749, 1.2015836541594085, 1.8883378078719442, 5.004966339124459, 9.485312439185861, 18.350052963982698, 32.10425937607427, 35.62003627252641]
# /var/folders/74/4jdnr7zn79q0h8cj7fy26vjm0000gn/T/ipykernel_62422/4207717623.py:83: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
# Peak flops for pdf parsing

# Peak flops on Polaris
peak_polaris = 44 * 1000 * 16  # TFLOPS * fp16

# Peak flops per GPU
nougat_single_gpu_flops = 430.85 * 0.001  # GFLOPS to TFLOPS

polaris_nougat_ngpus = [2 * 4, 32 * 4, 64 * 4, 128 * 4, 256 * 4]

peak_polaris_flops = [peak_polaris for _ in polaris_oreo_ngpus]
polaris_nougat_peak_flops = [
    nougat_single_gpu_flops * ngpus for ngpus in polaris_nougat_ngpus
]

x_values = [polaris_nougat_ngpus, polaris_oreo_ngpus]
y_values = [polaris_nougat_peak_flops, peak_polaris_flops]
labels = ["Polaris Nougat", "Peak Polaris"]
image_name = "scaling_relations_nougat_flops.pdf"
ylabel = "Peak TFLOPS"
plot_scaling_relations(x_values, y_values, labels, image_name, ylabel)

print("Num accelerators: ", polaris_ngpus)
print("Polaris Nougat Parser Peak TFlops: ", polaris_nougat_peak_flops)
print("Peak Polaris TFlops (fp16): ", peak_polaris)
# Out:
# Num accelerators:  [8, 128, 256, 512, 1024]
# Polaris Nougat Parser Peak TFlops:  [3.4468, 55.1488, 110.2976, 220.5952, 441.1904]
# Peak Polaris TFlops (fp16):  704000
# /var/folders/74/4jdnr7zn79q0h8cj7fy26vjm0000gn/T/ipykernel_47408/3580349046.py:66: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
# Peak flops on Polaris
peak_polaris = 44 * 1000 * 8  # TFLOPS * fp32

# Peak flops per GPU
oreo_single_gpu_flops = 40.73  # TFLOPS

polaris_oreo_ngpus = [2 * 4, 32 * 4, 64 * 4, 128 * 4, 256 * 4]

peak_polaris_flops = [peak_polaris for _ in polaris_oreo_ngpus]
polaris_oreo_peak_flops = [oreo_single_gpu_flops * ngpu for ngpu in polaris_oreo_ngpus]

x_values = [polaris_oreo_ngpus, polaris_oreo_ngpus]
y_values = [polaris_oreo_peak_flops, peak_polaris_flops]
labels = ["Polaris Oreo", "Peak Polaris"]
image_name = "scaling_relations_oreo_flops.pdf"
ylabel = "Peak TFLOPS"
plot_scaling_relations(x_values, y_values, labels, image_name, ylabel)

print("Num accelerators: ", polaris_ngpus)
print("Polaris Oreo Parser Peak TFlops: ", polaris_oreo_peak_flops)
print("Peak Polaris TFlops (fp32): ", peak_polaris)
# Out:
# Num accelerators:  [8, 128, 256, 512, 1024]
# Polaris Oreo Parser Peak TFlops:  [325.84, 5213.44, 10426.88, 20853.76, 41707.52]
# Peak Polaris TFlops (fp32):  352000
# /var/folders/74/4jdnr7zn79q0h8cj7fy26vjm0000gn/T/ipykernel_47408/3580349046.py:66: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
# Peak flops for semantic chunking

# Peak flops on Polaris (44pflops double precision)
peak_polaris = 44 * 1000 * 64  # TFLOPS * int8 quantization

# Peak flops per GPU
sfr_mistral_single_gpu_flops = 76.98  # GFLOPS to TFLOPS
pubmedbert_single_gpu_flops = 60.36  # GFLOPS to TFLOPS

polaris_ngpus = [2 * 4, 32 * 4, 64 * 4, 128 * 4, 256 * 4]

peak_polaris_flops = [peak_polaris for _ in polaris_oreo_ngpus]
mistral_peak_flops = [sfr_mistral_single_gpu_flops * ngpus for ngpus in polaris_ngpus]
pubmedbert_peak_flops = [pubmedbert_single_gpu_flops * ngpus for ngpus in polaris_ngpus]

x_values = [polaris_ngpus, polaris_ngpus, polaris_ngpus]
y_values = [mistral_peak_flops, pubmedbert_peak_flops, peak_polaris_flops]
labels = ["Polaris Mistral", "Polaris Pubmedbert", "Peak Polaris"]
image_name = "scaling_relations_peak_flops_semantic_chunking.pdf"
ylabel = "Peak TFLOPS"
plot_scaling_relations(x_values, y_values, labels, image_name, ylabel)

print("Num accelerators: ", polaris_ngpus)
print("Polaris Mistral Peak TFlops: ", mistral_peak_flops)
print("Polaris Pubmedbert Peak TFlops: ", pubmedbert_peak_flops)
print("Peak Polaris TFlops (int8): ", peak_polaris)
# Out:
# Num accelerators:  [8, 128, 256, 512, 1024]
# Polaris Mistral Peak TFlops:  [615.84, 9853.44, 19706.88, 39413.76, 78827.52]
# Polaris Pubmedbert Peak TFlops:  [482.88, 7726.08, 15452.16, 30904.32, 61808.64]
# Peak Polaris TFlops (int8):  2816000
# /var/folders/74/4jdnr7zn79q0h8cj7fy26vjm0000gn/T/ipykernel_47408/3580349046.py:66: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
polaris_nougat_ngpus = [2 * 4, 32 * 4, 64 * 4, 128 * 4, 256 * 4]
sunspot_ngpus = [
    1 * 12,
    2 * 12,
    4 * 12,
    8 * 12,
    16 * 12,
    32 * 12,
    64 * 12,
    96 * 12,
]

print("Polaris Accelerators", polaris_nougat_ngpus)
print("Sunspot Accelerators", sunspot_ngpus)
# Out:
# Polaris Accelerators [8, 128, 256, 512, 1024]
# Sunspot Accelerators [12, 24, 48, 96, 192, 384, 768, 1152]
